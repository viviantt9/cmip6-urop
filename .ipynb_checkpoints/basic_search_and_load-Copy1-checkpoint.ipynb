# %% [markdown]
# # Google Cloud CMIP6 Public Data: Basic Python Example
#
# This notebooks shows how to query the catalog and load the data using python

# %%
from matplotlib import pyplot as plt, animation
import numpy as np
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
import zarr
import fsspec

# %matplotlib notebook
# %config InlineBackend.figure_format = 'retina' 
plt.rcParams['figure.figsize'] = 12, 6

# %% [markdown]
# ## Browse Catalog
#
# The data catatalog is stored as a CSV file. Here we read it with Pandas.

# %%
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon         prw         gn
# 1     Amon         hus         gn
# 2     Amon        rlds         gn
# 3     Amon         psl         gn
# 4     Amon          ps         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %% [markdown]
# The columns of the dataframe correspond to the CMI6 controlled vocabulary. A beginners' guide to these terms is available in [this document](https://docs.google.com/document/d/1yUx6jr9EdedCOLd--CPdTfGDwEwzPpCF6p1jRmqx-0Q).
#
# Here we filter the data to find monthly surface air temperature for historical experiments.

# %%
df_ta = df.query("activity_id=='CMIP' & table_id == 'Amon' & variable_id == 'co2s' & experiment_id == 'historical'")
df_ta
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 6809          CMIP      NOAA-GFDL     GFDL-ESM4    historical   r2i1p1f1
# 6940          CMIP      NOAA-GFDL     GFDL-ESM4    historical   r3i1p1f1
# 18254         CMIP      NOAA-GFDL      GFDL-CM4    historical   r1i1p1f1
# 22137         CMIP           IPSL  IPSL-CM6A-LR    historical  r19i1p1f1
# 22458         CMIP           IPSL  IPSL-CM6A-LR    historical  r21i1p1f1
# ...            ...            ...           ...           ...        ...
# 521483        CMIP            MRI    MRI-ESM2-0    historical   r7i1p1f1
# 521497        CMIP            MRI    MRI-ESM2-0    historical   r9i1p1f1
# 521665        CMIP            MRI    MRI-ESM2-0    historical   r6i1p1f1
# 521916        CMIP           CMCC  CMCC-CM2-SR5    historical   r3i1p2f1
# 521923        CMIP           CMCC  CMCC-CM2-SR5    historical   r2i1p2f1
#
#        table_id variable_id grid_label  \
# 6809       Amon         tas        gr1
# 6940       Amon         tas        gr1
# 18254      Amon         tas        gr1
# 22137      Amon         tas         gr
# 22458      Amon         tas         gr
# ...         ...         ...        ...
# 521483     Amon         tas         gn
# 521497     Amon         tas         gn
# 521665     Amon         tas         gn
# 521916     Amon         tas         gn
# 521923     Amon         tas         gn
#
#                                                    zstore  dcpp_init_year  \
# 6809    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 6940    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 18254   gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 22137   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 22458   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# ...                                                   ...             ...
# 521483  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 521497  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 521665  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 521916  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
# 521923  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
#
#          version
# 6809    20180701
# 6940    20180701
# 18254   20180701
# 22137   20180803
# 22458   20180803
# ...          ...
# 521483  20210813
# 521497  20210813
# 521665  20210907
# 521916  20211108
# 521923  20211109
#
# [635 rows x 11 columns]

# %% [markdown]
# Now we do further filtering to find just the models from NCAR.

# %%
df_ta_ncar = df_ta.query('institution_id == "NCAR"')
df_ta_ncar
# Out:
#        activity_id institution_id        source_id experiment_id  member_id  \
# 55991         CMIP           NCAR      CESM2-WACCM    historical   r1i1p1f1
# 56019         CMIP           NCAR      CESM2-WACCM    historical   r2i1p1f1
# 56251         CMIP           NCAR      CESM2-WACCM    historical   r3i1p1f1
# 58639         CMIP           NCAR            CESM2    historical   r5i1p1f1
# 59435         CMIP           NCAR            CESM2    historical   r1i1p1f1
# 59801         CMIP           NCAR            CESM2    historical   r4i1p1f1
# 60054         CMIP           NCAR            CESM2    historical   r6i1p1f1
# 60739         CMIP           NCAR            CESM2    historical   r3i1p1f1
# 61163         CMIP           NCAR            CESM2    historical   r2i1p1f1
# 64503         CMIP           NCAR            CESM2    historical   r8i1p1f1
# 64862         CMIP           NCAR            CESM2    historical   r7i1p1f1
# 65924         CMIP           NCAR            CESM2    historical   r9i1p1f1
# 66119         CMIP           NCAR            CESM2    historical  r10i1p1f1
# 200509        CMIP           NCAR            CESM2    historical  r11i1p1f1
# 385096        CMIP           NCAR        CESM2-FV2    historical   r1i1p1f1
# 385921        CMIP           NCAR  CESM2-WACCM-FV2    historical   r1i1p1f1
# 420365        CMIP           NCAR        CESM2-FV2    historical   r3i1p1f1
# 420783        CMIP           NCAR  CESM2-WACCM-FV2    historical   r2i1p1f1
# 421814        CMIP           NCAR        CESM2-FV2    historical   r2i1p1f1
# 422081        CMIP           NCAR  CESM2-WACCM-FV2    historical   r3i1p1f1
#
#        table_id variable_id grid_label  \
# 55991      Amon         tas         gn
# 56019      Amon         tas         gn
# 56251      Amon         tas         gn
# 58639      Amon         tas         gn
# 59435      Amon         tas         gn
# 59801      Amon         tas         gn
# 60054      Amon         tas         gn
# 60739      Amon         tas         gn
# 61163      Amon         tas         gn
# 64503      Amon         tas         gn
# 64862      Amon         tas         gn
# 65924      Amon         tas         gn
# 66119      Amon         tas         gn
# 200509     Amon         tas         gn
# 385096     Amon         tas         gn
# 385921     Amon         tas         gn
# 420365     Amon         tas         gn
# 420783     Amon         tas         gn
# 421814     Amon         tas         gn
# 422081     Amon         tas         gn
#
#                                                    zstore  dcpp_init_year  \
# 55991   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 56019   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 56251   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 58639   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r5...             NaN
# 59435   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 59801   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r4...             NaN
# 60054   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r6...             NaN
# 60739   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r3...             NaN
# 61163   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r2...             NaN
# 64503   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r8...             NaN
# 64862   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r7...             NaN
# 65924   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r9...             NaN
# 66119   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 200509  gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 385096  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 385921  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 420365  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 420783  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 421814  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 422081  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
#
#          version
# 55991   20190227
# 56019   20190227
# 56251   20190227
# 58639   20190308
# 59435   20190308
# 59801   20190308
# 60054   20190308
# 60739   20190308
# 61163   20190308
# 64503   20190311
# 64862   20190311
# 65924   20190311
# 66119   20190313
# 200509  20190514
# 385096  20191120
# 385921  20191120
# 420365  20200226
# 420783  20200226
# 421814  20200226
# 422081  20200226

# %% [markdown]
# ## Load Data
#
# Now we will load a single store using fsspec, zarr, and xarray.

# %%
# get the path to a specific zarr store (the first one from the dataframe above)
zstore = df_ta_ncar.zstore.values[-1]
print(zstore)

# create a mutable-mapping-style interface to the store
mapper = fsspec.get_mapper(zstore)

# open it using xarray and zarr
ds = xr.open_zarr(mapper, consolidated=True)
ds
# Out:
# gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/historical/r3i1p1f1/Amon/tas/gn/v20200226/
# <xarray.Dataset>
# Dimensions:    (lat: 96, nbnd: 2, lon: 144, time: 1980)
# Coordinates:
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#     lat_bnds   (lat, nbnd) float64 dask.array<chunksize=(96, 2), meta=np.ndarray>
#   * lon        (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     lon_bnds   (lon, nbnd) float64 dask.array<chunksize=(144, 2), meta=np.ndarray>
#   * time       (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     time_bnds  (time, nbnd) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (time, lat, lon) float32 dask.array<chunksize=(990, 96, 144), meta=np.ndarray>
# Attributes: (12/48)
#     Conventions:                     CF-1.7 CMIP-6.2
#     DODS_EXTRA.Unlimited_Dimension:  time
#     activity_id:                     CMIP
#     branch_method:                   standard
#     branch_time_in_child:            674885.0
#     branch_time_in_parent:           10950.0
#     ...                              ...
#     tracking_id:                     hdl:21.14100/1f8528d8-4f40-4e1b-a345-40e...
#     variable_id:                     tas
#     variant_info:                    CMIP6 CESM2 historical ensemble with WAC...
#     variant_label:                   r3i1p1f1
#     netcdf_tracking_ids:             hdl:21.14100/1f8528d8-4f40-4e1b-a345-40e...
#     version_id:                      v20200226

# %%
clevs = np.linspace(200, 320, 121)
latitude = ds.tas.lat
longitude = ds.tas.lon
data=ds.tas.isel(time=0).as_numpy()
np.savetxt("surface_temp.csv", data, delimiter=",")

# %%
cs = plt.contourf(longitude, latitude, data, clevs)
plt.show()

# %%
fig = plt.figure(1)
ax = plt.subplot(1,1,1,projection=ccrs.PlateCarree())
ax.coastlines()
latitude = ds.tas.lat
longitude = ds.tas.lon
clevs = np.linspace(200, 320, 121)
ims = []
for year in range(0, 2):
    data = ds.tas.isel(time=year).as_numpy()
    plt.title(f'year: {year}')
    cs = ax.contourf(longitude, latitude, data, clevs)
    ims.append(cs.collections)
ani = animation.ArtistAnimation(fig, ims, interval=100)
ani
# Out:
# <img src="data:image/png;base64,..." width="864">

# %%
plt.show()

# %% [markdown]
# Plot a map from a specific date.

# %%
fig = plt.figure(1, figsize = [30,13])
ax = plt.subplot(1, 1, 1, projection = ccrs.PlateCarree())
ax.coastlines()

dates = []
images = []
images.append(ds['tas'].isel(time=1950).plot.pcolormesh(ax=ax, cmap='coolwarm'))
for x in range(1951, 1953):
    dates.append(str(x))
def image_():
    ds['tas'].isel(time=date).plot.pcolormesh(ax=ax, cmap='coolwarm')
print(ds['tas'].isel(time=1950))
anim = animation.FuncAnimation(fig, images, interval=1000, repeat_delay = 1000)
# Out:
# <xarray.DataArray 'tas' (lat: 96, lon: 144)>
# dask.array<getitem, shape=(96, 144), dtype=float32, chunksize=(96, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     time     object 2012-07-15 12:00:00
# Attributes: (12/20)
#     _ChunkSizes:    [1, 96, 144]
#     cell_measures:  area: areacella
#     cell_methods:   area: time: mean
#     comment:        TREFHT
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %% [markdown]
# Create a timeseries of global-average surface air temperature. For this we need the area weighting factor for each gridpoint.

# %%
df_area = df.query("variable_id == 'areacella' & source_id == 'CESM2'")
ds_area = xr.open_zarr(fsspec.get_mapper(df_area.zstore.values[0]), consolidated=True)
ds_area

# %%
total_area = ds_area.areacella.sum(dim=['lon', 'lat'])
ta_timeseries = (ds.tas * ds_area.areacella).sum(dim=['lon', 'lat']) / total_area
ta_timeseries

# %% [markdown]
# By default the data are loaded lazily, as Dask arrays. Here we trigger computation explicitly.

# %%
# %time ta_timeseries.load()

# %%
ta_timeseries.plot(label='monthly')
ta_timeseries.rolling(time=12).mean().plot(label='12 month rolling mean')
plt.legend()
plt.title('Global Mean Surface Air Temperature')
